# %% [markdown]
# # Creando el directrio env

# %%
from IPython.display import Image
Image(filename="img\captura1.jpg", width=800, height=500)

# %% [markdown]
# # Activando entorno virtual

# %%
from IPython.display import Image
Image(filename="img\captura2.jpg", width=800, height=500)

# %% [markdown]
# Procedemos a verificar las bibliotecas instaladas en el entorno virual(no se obtiene respuesta ya que aun no se instala ninguna biblioteca)

# %%
from IPython.display import Image
Image(filename="img\captura3.jpg", width=800, height=500)

# %% [markdown]
# Se instala la biblioteca python-dateutil

# %%
from IPython.display import Image
Image(filename="img\captura4.jpg", width=800, height=500)

# %% [markdown]
# Se verifica con pip freeze que este instalada la biblioteca

# %%
from IPython.display import Image
Image(filename="img\captura5.jpg", width=800, height=500)

# %% [markdown]
# Por ultimo desactivamos nuestro entorno virtual

# %%
from IPython.display import Image
Image(filename="img\captura6.jpg", width=800, height=500)
